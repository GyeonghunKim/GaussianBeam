# %%
# %load_ext autoreload
# %autoreload 2

# %%
from gaussian_beam.beam.beam import GaussianBeam
from gaussian_beam.components.lens import ThinLens
from gaussian_beam.components.sequence import Sequence
from gaussian_beam.utils.units import *

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
initial_beam = GaussianBeam(-10 * mm, [0.1 * mm, 0.13 * mm], 0, 10 * W, 10.6 * um)
lens_list = [
    ThinLens(20*mm * i, 5.5 * mm) for i in range(10) 
]
sequence = Sequence(lens_list, (-10 * mm, 220 * mm), initial_beam=initial_beam)

# %%
fig, ax = sequence.plot_xz()
