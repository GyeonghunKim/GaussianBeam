# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from gaussian_beam.beam.beam import GaussianBeam
from gaussian_beam.components.lens import Lens
from gaussian_beam.components.sequence import Sequence
from gaussian_beam.units import *

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
initial_beam = GaussianBeam(-10 * mm, 0.1 * mm, 0, 10 * W, 10.6 * um)
lens_list = [
    Lens(20*mm * i, 5.5 * mm) for i in range(10) 
]
sequence = Sequence(lens_list, (-10 * mm, 220 * mm), initial_beam=initial_beam)

# %%
fig, ax = sequence.plot_xz()
