# %%
# %load_ext autoreload
# %autoreload 2

# %%
from gaussian_beam.beam import GaussianBeam
from gaussian_beam.lens import Lens
from gaussian_beam.sequence import Sequence
from gaussian_beam.units import *

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
initial_beam = GaussianBeam(-10 * mm, 1 * mm, 1 * mm, 0, 10 * W, 10.6 * um)
lens_1 = Lens(0 * mm, 25.4 * mm)
lens_2 = Lens(76.4 * mm, 51 * mm)
sequence = Sequence([lens_1, lens_2], (-20 * mm, 100 * mm), initial_beam=initial_beam)

# %%
lens_1.name
# Out:
# 'Lens f=25.4mm at z=0.0mm'

# %%
fig, ax = sequence.plot_xz()
